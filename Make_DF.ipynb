# %%
import pandas as pd

# %%
# Load in csv
df23 = pd.read_csv("Resources/2023_stats.csv")
df23.head()
# Out:
#      Maryland Counties Units Sold 2023 Units Sold 2022 Units Sold % Chg  \
# 0      Allegany County             679             786          -13.60%
# 1  Anne Arundel County           7,013           9,214          -23.90%
# 2       Baltimore City           8,167           9,905          -17.50%
# 3     Baltimore County           8,463          10,498          -19.40%
# 4       Calvert County           1,144           1,539          -25.70%
#
#   Average Sales Price 2023 Average Sales Price 2022 Average Sales Price % Chg  \
# 0                $144,671                 $143,403                      0.90%
# 1                $563,516                 $531,520                      6.00%
# 2                $248,767                 $256,875                     -3.20%
# 3                $393,962                 $376,608                      4.60%
# 4                $482,633                 $470,219                      2.60%
#
# ...
