# %%
import pandas as pd

# %%
# Load in csv
df23 = pd.read_csv("Resources/2023_stats.csv")
df23.head()
# Out:
#               Counties  Units Sold 2023  Units Sold 2022  Units Sold % Chg  \
# 0      Allegany County              679              786            -0.136
# 1  Anne Arundel County             7013             9214            -0.239
# 2       Baltimore City             8167             9905            -0.175
# 3     Baltimore County             8463            10498            -0.194
# 4       Calvert County             1144             1539            -0.257
#
#    Average Price 2023  Average Price 2022  Price % Chg  Median Price 2023  \
# 0              144671              143403        0.009             130000
# 1              563516              531520        0.060             470000
# 2              248767              256875       -0.032             215000
# 3              393962              376608        0.046             332000
# 4              482633              470219        0.026             425000
#
#    Median Price 2022  Median  % Chg  Med Days Market 2023  \
# ...
